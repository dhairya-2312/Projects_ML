# %% [markdown]
# # ***Import the required Libraries and dependencies***

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics

# %% [markdown]
# # ***Data Collection and Analysis***

# %%
# Loading data from csv file to a pandas DataFrame
insurance_dataset = pd.read_csv('/content/insurance.csv')

# %%
# Printing the first 5 rows of the acquired DataFrame
insurance_dataset.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
# Total number of Rows and Columns
insurance_dataset.shape
# Out:
# (1338, 7)

# %%
# Getting Information about the Dataset
insurance_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %% [markdown]
# # ***Features according to Category:***
#
#
# 1.   Sex
# 2.   Smoker
# 3.   Region

# %%
# Check the total number of missing values
insurance_dataset.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %% [markdown]
# # ***Data Analysis***

# %%
# Describing the Statistical Measures of the acquired Dataset
insurance_dataset.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
# Age Distribution
sns.set()
plt.figure(figsize = (9,9))
sns.distplot(insurance_dataset['age'], color='Blue')
plt.title('Age Distribution')
plt.show()
# Out:
# <ipython-input-34-d39665a75614>:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(insurance_dataset['age'], color='Blue')

# %%
# Gender Column
plt.figure(figsize = (9,9))
sns.countplot(x = 'sex', data = insurance_dataset, color='blue')
plt.title('Sex Distribution')
plt.show()

# %%
insurance_dataset['sex'].value_counts()
# Out:
# sex
# male      676
# female    662
# Name: count, dtype: int64

# %%
# BMI Distribution
plt.figure(figsize = (9,9))
sns.distplot(insurance_dataset['bmi'], color='blue')
plt.title('BMI Distribution')
plt.show()
# Out:
# <ipython-input-36-5bf4bf98628e>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(insurance_dataset['bmi'], color='blue')

# %% [markdown]
# ### ***Underweight: BMI less than 18.5***
# ### ***Normal weight: BMI 18.5 - 24.9***
# ### ***Overweight: BMI 25 - 29.9***
# ### ***Obesity Class I(Moderate): BMI 30 - 34.9***
# ### ***Obesity Class II (Severe): BMI 35 - 39.9***
# ### ***Obesity Class III (Very Severe or Morbid Obesity): BMI 40 and above***

# %%
# Children Distribution
plt.figure(figsize = (9,9))
sns.countplot(x = 'children', data = insurance_dataset, palette = 'Set1')
plt.title('Children Distribution')
plt.show()
# Out:
# <ipython-input-37-c17fbce45510>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x = 'children', data = insurance_dataset, palette = 'Set1')

# %%
insurance_dataset['children'].value_counts()
# Out:
# children
# 0    574
# 1    324
# 2    240
# 3    157
# 4     25
# 5     18
# Name: count, dtype: int64

# %%
# Smoker Distribution
plt.figure(figsize = (9,9))
sns.countplot(x = 'smoker', data = insurance_dataset, palette = 'Set1')
plt.title('Smoker Distribution')
plt.show()
# Out:
# <ipython-input-38-01b858bf851b>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x = 'smoker', data = insurance_dataset, palette = 'Set1')

# %%
insurance_dataset['smoker'].value_counts()
# Out:
# smoker
# no     1064
# yes     274
# Name: count, dtype: int64

# %%
# Region Distribution
plt.figure(figsize = (9,9))
sns.countplot(x = 'region', data = insurance_dataset, palette = 'Set1')
plt.title('Region Distribution')
plt.show()
# Out:
# <ipython-input-39-8fc2a0a05ec5>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x = 'region', data = insurance_dataset, palette = 'Set1')

# %%
insurance_dataset['region'].value_counts()
# Out:
# region
# southeast    364
# southwest    325
# northwest    325
# northeast    324
# Name: count, dtype: int64

# %%
# Charges distribution
plt.figure(figsize = (9,9))
sns.distplot(insurance_dataset['charges'], color='blue')
plt.title('CHarges Distribution')
plt.show()
# Out:
# <ipython-input-40-4d508f021f7f>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(insurance_dataset['charges'], color='blue')

# %% [markdown]
# # ***Data Pre-Processing***

# %% [markdown]
# Encoding the Categorical values

# %%
# Encoding the sex column
insurance_dataset.replace({'sex' : {'male' : 0, 'female' : 1}}, inplace = True)
# Encoding the smoker column
insurance_dataset.replace({'smoker' : {'yes' : 0, 'no' : 1}}, inplace = True)
# encoding the region column
insurance_dataset.replace({'region' : {'southeast' : 0, 'southwest' : 1, 'northeast' : 2, 'northwest' : 3}}, inplace = True)

# %% [markdown]
# Splitting the Features and Targets

# %%
X = insurance_dataset.drop(columns = 'charges', axis = 1)
Y = insurance_dataset['charges']

# %%
print(X)
# Out:
#       age  sex     bmi  children  smoker  region
# 0      19    1  27.900         0       0       1
# 1      18    0  33.770         1       1       0
# 2      28    0  33.000         3       1       0
# 3      33    0  22.705         0       1       3
# 4      32    0  28.880         0       1       3
# ...   ...  ...     ...       ...     ...     ...
# 1333   50    0  30.970         3       1       3
# 1334   18    1  31.920         0       1       2
# 1335   18    1  36.850         0       1       0
# 1336   21    1  25.800         0       1       1
# 1337   61    1  29.070         0       0       3
#
# [1338 rows x 6 columns]

# %%
print(Y)
# Out:
# 0       16884.92400
# 1        1725.55230
# 2        4449.46200
# 3       21984.47061
# 4        3866.85520
#            ...
# 1333    10600.54830
# 1334     2205.98080
# 1335     1629.83350
# 1336     2007.94500
# 1337    29141.36030
# Name: charges, Length: 1338, dtype: float64

# %% [markdown]
# Splitting thje data into Training data and Testing data

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, random_state = 2)

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (1338, 6) (1070, 6) (268, 6)

# %% [markdown]
# # ***Model Training(Linear Regression)***

# %%
# Loading the Linear Regression Model
regressor = LinearRegression()

# %%
regressor.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %% [markdown]
# # ***Model Evaluation***

# %%
# Prediction on Training Data
training_data_prediction = regressor.predict(X_train)

# %%
# R squared value
r2_train = metrics.r2_score(Y_train, training_data_prediction)
print('R squared value : ', r2_train)
# Out:
# R squared value :  0.751505643411174

# %% [markdown]
# # ***Building  a predictive system***

# %%
input_data = (33, 3, 24, 72, 0, 9)

# Convert the input data to numpy array
input_data_as_numpy_array = np.asarray(input_data)
# Reshape the array
input_data_reshaped = input_data_as_numpy_array.reshape(1, -1)

prediction = regressor.predict(input_data_reshaped)
print(prediction)
print('The cost of Medical insurance iS USD ', prediction[0])
# Out:
# [71357.65958252]
# The cost of Medical insurance iS USD  71357.65958251902
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:465: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
